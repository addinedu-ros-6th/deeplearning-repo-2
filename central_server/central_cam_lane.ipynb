# %%
import cv2
import numpy as np
import socket
import struct
import time
from threading import Thread

# Sobel 연산을 통한 x 또는 y 방향 경계 계산 함수
def abs_sobel_thresh(img, orient='x', thresh_min=25, thresh_max=255):
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS).astype(float)
    l_channel = hls[:, :, 1]

    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 1, 0))
    elif orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 0, 1))
    else:
        raise ValueError("orient must be 'x' or 'y'")

    scaled_sobel = np.uint8(255 * abs_sobel / np.max(abs_sobel))

    binary_output = np.zeros_like(scaled_sobel)
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

    return binary_output

# 색상 정보를 기반으로 특정 범위에 해당하는 색상을 강조하는 함수
def color_threshold(image, sthresh=(0, 255), vthresh=(0, 255)):
    hls = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
    s_channel = hls[:, :, 2]

    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= sthresh[0]) & (s_channel <= sthresh[1])] = 1

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    v_channel = hsv[:, :, 2]

    v_binary = np.zeros_like(v_channel)
    v_binary[(v_channel >= vthresh[0]) & (vthresh[1] >= v_channel)] = 1

    output = np.zeros_like(s_channel)
    output[(s_binary == 1) & (v_binary == 1)] = 1

    return output

# 이미지의 특정 영역(ROI)을 선택하는 함수
def apply_roi(image):
    height = image.shape[0]
    mask = np.zeros_like(image)

    polygon = np.array([[
        (0, int(height * 2/5)),
        (image.shape[1], int(height * 2/5)),
        (image.shape[1], height),
        (0, height)
    ]], np.int32)

    cv2.fillPoly(mask, polygon, 255)
    roi_image = cv2.bitwise_and(image, mask)
    return roi_image

# 카메라 매트릭스와 왜곡 계수
mtx = np.array([[1.15753008e+03, 0.00000000e+00, 6.75382833e+02],
                [0.00000000e+00, 1.15189955e+03, 3.86729350e+02],
                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])
dist = np.array([[-0.26706898,  0.10305542, -0.00088013,  0.00080643, -0.19574027]])

left_speed = 0
right_speed = 0

def handle_client(rpi_conn):
    global left_speed, right_speed
    try:
        while True:
            header = b''
            while len(header) < 2:
                header += rpi_conn.recv(2 - len(header))

            # frame data
            if header == b'SF':
                size_data = b''
                while len(size_data) < 4:
                    packet = rpi_conn.recv(4 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                frame_size = struct.unpack(">L", size_data)[0]

                frame_data = b''
                while len(frame_data) < frame_size:
                    packet = rpi_conn.recv(frame_size - len(frame_data))
                    if not packet:
                        break
                    frame_data += packet

                rpi_conn.recv(1)  # \n 받기

                frame = cv2.imdecode(np.frombuffer(frame_data, np.uint8), cv2.IMREAD_COLOR)
                #cv2.imshow("Original frame", frame)

                if frame is not None:
                    # 카메라 캘리브레이션 적용
                    undist_frame = cv2.undistort(frame, mtx, dist, None, mtx)

                    # 차선 검출
                    gradx = abs_sobel_thresh(undist_frame, orient='x', thresh_min=20, thresh_max=100)
                    grady = abs_sobel_thresh(undist_frame, orient='y', thresh_min=20, thresh_max=100)

                    # 색상 임계값 적용
                    c_binary = color_threshold(undist_frame, sthresh=(80, 255), vthresh=(50, 255))

                    # 최종 이진 이미지 생성
                    preprocessImage = np.zeros_like(undist_frame[:, :, 0])
                    preprocessImage[((gradx == 1) & (grady == 1)) | (c_binary == 1)] = 255

                    # ROI 적용
                    preprocessImage = apply_roi(preprocessImage)

                    # 무게 중심을 기반으로 모터 제어
                    midpoint = preprocessImage.shape[1] // 2

                    nonzero = preprocessImage.nonzero()
                    nonzeroy = np.array(nonzero[0])
                    nonzerox = np.array(nonzero[1])

                    left_lane_inds = (nonzerox < midpoint)
                    right_lane_inds = (nonzerox >= midpoint)

                    leftx = nonzerox[left_lane_inds]
                    lefty = nonzeroy[left_lane_inds]
                    rightx = nonzerox[right_lane_inds]
                    righty = nonzeroy[right_lane_inds]

                    # 왼쪽 차선의 무게중심 계산 및 표시
                    if len(leftx) > 0 and len(lefty) > 0:
                        left_center_x = int(np.mean(leftx))
                        left_center_y = int(np.mean(lefty))
                        cv2.circle(undist_frame, (left_center_x, left_center_y), 5, (0, 255, 0), -1)
                    else:
                        left_center_x = None
                        left_center_y = None

                    # 오른쪽 차선의 무게중심 계산 및 표시
                    if len(rightx) > 0 and len(righty) > 0:
                        right_center_x = int(np.mean(rightx))
                        right_center_y = int(np.mean(righty))
                        cv2.circle(undist_frame, (right_center_x, right_center_y), 5, (0, 255, 0), -1)
                    else:
                        right_center_x = None
                        right_center_y = None

                    # 두 차선 무게중심의 중앙점 계산 및 표시
                    if left_center_x is not None and right_center_x is not None:
                        mid_center_x = int((left_center_x + right_center_x) / 2)
                        mid_center_y = int((left_center_y + right_center_y) / 2)
                        cv2.circle(undist_frame, (mid_center_x, mid_center_y), 5, (255, 0, 0), -1)

                        # 이미지 중앙과의 편차 계산
                        image_center_x = undist_frame.shape[1] // 2
                        deviation = mid_center_x - image_center_x

                        # 모터 값 계산 및 전송
                        max_speed = 100  # 최대 속도
                        base_speed = 50  # 기본 속도
                        max_deviation = undist_frame.shape[1] // 2

                        normalized_deviation = deviation / max_deviation
                        normalized_deviation = np.clip(normalized_deviation, -1, 1)

                        left_speed = base_speed - (normalized_deviation * base_speed)
                        right_speed = base_speed + (normalized_deviation * base_speed)

                        left_speed = int(np.clip(left_speed, 0, max_speed))
                        right_speed = int(np.clip(right_speed, 0, max_speed))
                        

                    # 화면에 디버그용으로 표시
                    lane_overlay = np.zeros_like(undist_frame)
                    lane_overlay[preprocessImage == 255] = [0, 0, 255]
                    combined = cv2.addWeighted(undist_frame, 0.7, lane_overlay, 1.0, 0)
                    cv2.imshow("Lane Detection", combined)

                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        break
                else:
                    print("Error: Unable to decode frame")

            # status data
            elif header == b'CS':
                status_data = b''
                while len(status_data) < 1:
                    packet = rpi_conn.recv(1 - len(status_data))
                    if not packet:
                        break
                    status_data += packet

                rpi_conn.recv(1)  # \n 받기

                status = int.from_bytes(status_data, byteorder="big")
                if status == 1:
                    print("status:", status)
                else:
                    print("status", status)

    except Exception as e:
        print(f"Error receiving or displaying frame: {e}")

    finally:
        rpi_conn.close()
        cv2.destroyAllWindows()

def send_motor_value(rpi_conn):
    global left_speed, right_speed
    while True:
        start = 60
        motor_command = start.to_bytes(1, byteorder="big") + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n" 

        try:
            rpi_conn.sendall(motor_command)
            print(f"send motor_command {motor_command}")
        except Exception as e:
            print(f"Error sending motor command: {e}")
        
        time.sleep(1)  # 2~5초에 한번 쏴주는것만으로도 충분함. 타임 슬립없으면 충돌남.
                

if __name__ == "__main__":

    # 서버 설정
    server_ip = "192.168.45.66"
    rpi_server_port = 3141

    rpi_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    rpi_server_socket.bind((server_ip, rpi_server_port))
    rpi_server_socket.listen(1)
    print(f"서버가 {server_ip} : {rpi_server_port}에서 대기 중입니다...")

    rpi_conn, addr = rpi_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")
    rpi_conn.settimeout(None)

    client_thread = Thread(target=handle_client, args=(rpi_conn,))
    client_thread.start()

    motor_cmd_thread = Thread(target=send_motor_value, args=(rpi_conn,))
    motor_cmd_thread.start()

    client_thread.join()
    motor_cmd_thread.join()

    rpi_conn.close()
    rpi_server_socket.close()
    cv2.destroyAllWindows()
# Out:
# 서버가 192.168.45.66 : 3141에서 대기 중입니다...
# 클라이언트 ('192.168.45.23', 40968)와 연결되었습니다.
# send motor_command b'<\x00\x00\n'
# status: 1
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# send motor_command b'<30\n'
# Error sending motor command: [Errno 104] Connection reset by peer
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 248
#     245 motor_cmd_thread = Thread(target=send_motor_value, args=(rpi_conn,))
#     246 motor_cmd_thread.start()
# --> 248 client_thread.join()
#     249 motor_cmd_thread.join()
#     251 rpi_conn.close()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe

# %%
import cv2
import numpy as np
import socket
import struct
import time
from threading import Thread

# Sobel 연산을 통한 x 또는 y 방향 경계 계산 함수
def abs_sobel_thresh(img, orient='x', thresh_min=25, thresh_max=255):
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS).astype(float)
    l_channel = hls[:, :, 1]

    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 1, 0))
    elif orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 0, 1))
    else:
        raise ValueError("orient must be 'x' or 'y'")

    scaled_sobel = np.uint8(255 * abs_sobel / np.max(abs_sobel))

    binary_output = np.zeros_like(scaled_sobel)
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

    return binary_output

# 색상 정보를 기반으로 특정 범위에 해당하는 색상을 강조하는 함수
def color_threshold(image, sthresh=(0, 255), vthresh=(0, 255)):
    hls = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
    s_channel = hls[:, :, 2]

    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= sthresh[0]) & (s_channel <= sthresh[1])] = 1

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    v_channel = hsv[:, :, 2]

    v_binary = np.zeros_like(v_channel)
    v_binary[(v_channel >= vthresh[0]) & (vthresh[1] >= v_channel)] = 1

    output = np.zeros_like(s_channel)
    output[(s_binary == 1) & (v_binary == 1)] = 1

    return output

# 이미지의 특정 영역(ROI)을 선택하는 함수
def apply_roi(image):
    height = image.shape[0]
    mask = np.zeros_like(image)

    polygon = np.array([[
        (0, int(height * 2/5)),
        (image.shape[1], int(height * 2/5)),
        (image.shape[1], height),
        (0, height)
    ]], np.int32)

    cv2.fillPoly(mask, polygon, 255)
    roi_image = cv2.bitwise_and(image, mask)
    return roi_image

# 카메라 매트릭스와 왜곡 계수
mtx = np.array([[1.15753008e+03, 0.00000000e+00, 6.75382833e+02],
                [0.00000000e+00, 1.15189955e+03, 3.86729350e+02],
                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])
dist = np.array([[-0.26706898,  0.10305542, -0.00088013,  0.00080643, -0.19574027]])

left_speed = 0
right_speed = 0

def handle_client(rpi_conn):
    global left_speed, right_speed
    try:
        while True:
            header = b''
            while len(header) < 2:
                header += rpi_conn.recv(2 - len(header))

            # frame data
            if header == b'SF':
                size_data = b''
                while len(size_data) < 4:
                    packet = rpi_conn.recv(4 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                frame_size = struct.unpack(">L", size_data)[0]

                frame_data = b''
                while len(frame_data) < frame_size:
                    packet = rpi_conn.recv(frame_size - len(frame_data))
                    if not packet:
                        break
                    frame_data += packet

                rpi_conn.recv(1)  # \n 받기

                frame = cv2.imdecode(np.frombuffer(frame_data, np.uint8), cv2.IMREAD_COLOR)

                if frame is not None:
                    # 카메라 캘리브레이션 적용
                    undist_frame = cv2.undistort(frame, mtx, dist, None, mtx)

                    # 차선 검출
                    gradx = abs_sobel_thresh(undist_frame, orient='x', thresh_min=20, thresh_max=100)
                    grady = abs_sobel_thresh(undist_frame, orient='y', thresh_min=20, thresh_max=100)

                    # 색상 임계값 적용
                    c_binary = color_threshold(undist_frame, sthresh=(30, 255), vthresh=(120, 255))

                    # 최종 이진 이미지 생성
                    preprocessImage = np.zeros_like(undist_frame[:, :, 0])
                    preprocessImage[((gradx == 1) & (grady == 1)) | (c_binary == 1)] = 255

                    # ROI 적용
                    preprocessImage = apply_roi(preprocessImage)
                    
                    # 무게 중심을 기반으로 모터 제어
                    midpoint = preprocessImage.shape[1] // 2

                    nonzero = preprocessImage.nonzero()
                    nonzeroy = np.array(nonzero[0])
                    nonzerox = np.array(nonzero[1])

                    left_lane_inds = (nonzerox < midpoint)
                    right_lane_inds = (nonzerox >= midpoint)

                    leftx = nonzerox[left_lane_inds]
                    lefty = nonzeroy[left_lane_inds]
                    rightx = nonzerox[right_lane_inds]
                    righty = nonzeroy[right_lane_inds]

                    # 왼쪽 차선의 무게중심 계산 및 표시
                    if len(leftx) > 0 and len(lefty) > 0:
                        left_center_x = int(np.mean(leftx))
                        left_center_y = int(np.mean(lefty))
                        cv2.circle(undist_frame, (left_center_x, left_center_y), 5, (0, 255, 0), -1)
                    else:
                        left_center_x = None
                        left_center_y = None

                    # 오른쪽 차선의 무게중심 계산 및 표시
                    if len(rightx) > 0 and len(righty) > 0:
                        right_center_x = int(np.mean(rightx))
                        right_center_y = int(np.mean(righty))
                        cv2.circle(undist_frame, (right_center_x, right_center_y), 5, (0, 255, 0), -1)
                    else:
                        right_center_x = None
                        right_center_y = None

                    # 두 차선 무게중심의 중앙점 계산 및 표시
                    if left_center_x is not None and right_center_x is not None:
                        mid_center_x = int((left_center_x + right_center_x) / 2)
                        mid_center_y = int((left_center_y + right_center_y) / 2)
                        cv2.circle(undist_frame, (mid_center_x, mid_center_y), 5, (255, 0, 0), -1)

                        # 이미지 중앙과의 편차 계산
                        image_center_x = undist_frame.shape[1] // 2
                        deviation = mid_center_x - image_center_x

                        # 모터 값 계산 및 전송
                        max_speed = 100  # 최대 속도
                        base_speed = 40  # 기본 속도
                        max_deviation = undist_frame.shape[1] // 2

                        normalized_deviation = deviation / max_deviation
                        normalized_deviation = np.clip(normalized_deviation, -10, 10)

                        left_speed = base_speed - (normalized_deviation * base_speed)
                        right_speed = base_speed + (normalized_deviation * base_speed)

                        left_speed = int(np.clip(left_speed, 0, max_speed))
                        right_speed = int(np.clip(right_speed, 0, max_speed))
                        

                    # 화면에 디버그용으로 표시
                    lane_overlay = np.zeros_like(undist_frame)
                    lane_overlay[preprocessImage == 255] = [0, 0, 255]
                    combined = cv2.addWeighted(undist_frame, 0.7, lane_overlay, 1.0, 0)
                    cv2.imshow("Lane Detection", combined)

                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        break
                else:
                    print("Error: Unable to decode frame")

            # status data
            elif header == b'CS':
                status_data = b''
                while len(status_data) < 1:
                    packet = rpi_conn.recv(1 - len(status_data))
                    if not packet:
                        break
                    status_data += packet

                rpi_conn.recv(1)  # \n 받기

                status = int.from_bytes(status_data, byteorder="big")
                if status == 1:
                    print("status:", status)
                else:
                    print("status", status)

    except Exception as e:
        print(f"Error receiving or displaying frame: {e}")

    finally:
        rpi_conn.close()
        cv2.destroyAllWindows()

def send_motor_value(rpi_conn):
    global left_speed, right_speed
    while True:
        start = 60
        motor_command = start.to_bytes(1, byteorder="big") + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n" 

        try:
            rpi_conn.sendall(motor_command)
            print(f"send motor_command {motor_command}")
            print(f"motor value: {left_speed}, {right_speed}")
        except Exception as e:
            print(f"Error sending motor command: {e}")
        
        time.sleep(1)  # 2~5초에 한번 쏴주는것만으로도 충분함. 타임 슬립없으면 충돌남.
                

if __name__ == "__main__":

    # 서버 설정
    server_ip = "192.168.0.134"
    rpi_server_port = 3141

    rpi_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    rpi_server_socket.bind((server_ip, rpi_server_port))
    rpi_server_socket.listen(1)
    print(f"서버가 {server_ip} : {rpi_server_port}에서 대기 중입니다...")

    rpi_conn, addr = rpi_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")
    rpi_conn.settimeout(None)

    client_thread = Thread(target=handle_client, args=(rpi_conn,))
    client_thread.start()

    motor_cmd_thread = Thread(target=send_motor_value, args=(rpi_conn,))
    motor_cmd_thread.start()

    client_thread.join()
    motor_cmd_thread.join()

    rpi_conn.close()
    rpi_server_socket.close()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 234
#     231 rpi_server_port = 3141
#     233 rpi_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# --> 234 rpi_server_socket.bind((server_ip, rpi_server_port))
#     235 rpi_server_socket.listen(1)
#     236 print(f"서버가 {server_ip} : {rpi_server_port}에서 대기 중입니다...")
#
# OSError: [Errno 98] Address already in use

# %% [markdown]
# ### 차선 검출 후 모터 값 전송 및 pollinaiton에서 객체 검출 정보 수신

# %%
import cv2
import numpy as np
import socket
import struct
import time
from threading import Thread

# Sobel 연산을 통한 x 또는 y 방향 경계 계산 함수
def abs_sobel_thresh(img, orient='x', thresh_min=25, thresh_max=255):
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS).astype(float)
    l_channel = hls[:, :, 1]

    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 1, 0))
    elif orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 0, 1))
    else:
        raise ValueError("orient must be 'x' or 'y'")

    scaled_sobel = np.uint8(255 * abs_sobel / np.max(abs_sobel))

    binary_output = np.zeros_like(scaled_sobel)
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

    return binary_output

# 색상 정보를 기반으로 특정 범위에 해당하는 색상을 강조하는 함수
def color_threshold(image, sthresh=(0, 255), vthresh=(0, 255)):
    hls = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
    s_channel = hls[:, :, 2]

    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= sthresh[0]) & (s_channel <= sthresh[1])] = 1

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    v_channel = hsv[:, :, 2]

    v_binary = np.zeros_like(v_channel)
    v_binary[(v_channel >= vthresh[0]) & (vthresh[1] >= v_channel)] = 1

    output = np.zeros_like(s_channel)
    output[(s_binary == 1) & (v_binary == 1)] = 1

    return output

# 이미지의 특정 영역(ROI)을 선택하는 함수
def apply_roi(image):
    height = image.shape[0]
    mask = np.zeros_like(image)

    polygon = np.array([[
        (0, int(height * 2/5)),
        (image.shape[1], int(height * 2/5)),
        (image.shape[1], height),
        (0, height)
    ]], np.int32)

    cv2.fillPoly(mask, polygon, 255)
    roi_image = cv2.bitwise_and(image, mask)
    return roi_image

# 카메라 매트릭스와 왜곡 계수
mtx = np.array([[1.15753008e+03, 0.00000000e+00, 6.75382833e+02],
                [0.00000000e+00, 1.15189955e+03, 3.86729350e+02],
                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])
dist = np.array([[-0.26706898,  0.10305542, -0.00088013,  0.00080643, -0.19574027]])

left_speed = 0
right_speed = 0

def handle_client(rpi_conn):
    global left_speed, right_speed
    try:
        while True:
            header = b''
            while len(header) < 2:
                header += rpi_conn.recv(2 - len(header))

            # frame data
            if header == b'SF':
                size_data = b''
                while len(size_data) < 4:
                    packet = rpi_conn.recv(4 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                frame_size = struct.unpack(">L", size_data)[0]

                frame_data = b''
                while len(frame_data) < frame_size:
                    packet = rpi_conn.recv(frame_size - len(frame_data))
                    if not packet:
                        break
                    frame_data += packet

                rpi_conn.recv(1)  # \n 받기

                frame = cv2.imdecode(np.frombuffer(frame_data, np.uint8), cv2.IMREAD_COLOR)

                if frame is not None:
                    # 카메라 캘리브레이션 적용
                    undist_frame = cv2.undistort(frame, mtx, dist, None, mtx)

                    # 차선 검출
                    gradx = abs_sobel_thresh(undist_frame, orient='x', thresh_min=20, thresh_max=100)
                    grady = abs_sobel_thresh(undist_frame, orient='y', thresh_min=20, thresh_max=100)

                    # 색상 임계값 적용
                    c_binary = color_threshold(undist_frame, sthresh=(80, 255), vthresh=(50, 255))

                    # 최종 이진 이미지 생성
                    preprocessImage = np.zeros_like(undist_frame[:, :, 0])
                    preprocessImage[((gradx == 1) & (grady == 1)) | (c_binary == 1)] = 255

                    # ROI 적용
                    preprocessImage = apply_roi(preprocessImage)

                    # 무게 중심을 기반으로 모터 제어
                    midpoint = preprocessImage.shape[1] // 2

                    nonzero = preprocessImage.nonzero()
                    nonzeroy = np.array(nonzero[0])
                    nonzerox = np.array(nonzero[1])

                    left_lane_inds = (nonzerox < midpoint)
                    right_lane_inds = (nonzerox >= midpoint)

                    leftx = nonzerox[left_lane_inds]
                    lefty = nonzeroy[left_lane_inds]
                    rightx = nonzerox[right_lane_inds]
                    righty = nonzeroy[right_lane_inds]

                    # 왼쪽 차선의 무게중심 계산 및 표시
                    if len(leftx) > 0 and len(lefty) > 0:
                        left_center_x = int(np.mean(leftx))
                        left_center_y = int(np.mean(lefty))
                        cv2.circle(undist_frame, (left_center_x, left_center_y), 5, (0, 255, 0), -1)
                    else:
                        left_center_x = None
                        left_center_y = None

                    # 오른쪽 차선의 무게중심 계산 및 표시
                    if len(rightx) > 0 and len(righty) > 0:
                        right_center_x = int(np.mean(rightx))
                        right_center_y = int(np.mean(righty))
                        cv2.circle(undist_frame, (right_center_x, right_center_y), 5, (0, 255, 0), -1)
                    else:
                        right_center_x = None
                        right_center_y = None

                    # 두 차선 무게중심의 중앙점 계산 및 표시
                    if left_center_x is not None and right_center_x is not None:
                        mid_center_x = int((left_center_x + right_center_x) / 2)
                        mid_center_y = int((left_center_y + right_center_y) / 2)
                        cv2.circle(undist_frame, (mid_center_x, mid_center_y), 5, (255, 0, 0), -1)

                        # 이미지 중앙과의 편차 계산
                        image_center_x = undist_frame.shape[1] // 2
                        deviation = mid_center_x - image_center_x

                        # 모터 값 계산 및 전송
                        max_speed = 100  # 최대 속도
                        base_speed = 50  # 기본 속도
                        max_deviation = undist_frame.shape[1] // 2

                        normalized_deviation = deviation / max_deviation
                        normalized_deviation = np.clip(normalized_deviation, -1, 1)

                        left_speed = base_speed - (normalized_deviation * base_speed)
                        right_speed = base_speed + (normalized_deviation * base_speed)

                        left_speed = int(np.clip(left_speed, 0, max_speed))
                        right_speed = int(np.clip(right_speed, 0, max_speed))
                        
                        
                        # # 수정된 코드:
                        # command_id = 'M'

                        # motor_command = struct.pack('2shh', command_id.encode('utf-8'), left_speed, right_speed)
                        # motor_command += b'\n'
                        # print(f"Sending motor command: {command_id} with speeds L: {left_speed}, R: {right_speed}")

                        #motor_command = b'M' + bytes([left_speed, right_speed]) + b'\n'
                        
                        # motor_command = bytes([10, left_speed, right_speed]) + b'\n'
                        # motor_command = b'M' + b'R' if deviation > 0 else b'L' + right_speed.to_bytes(2, byteorder="big") + b'\n'

                        # motor_command = b"M" + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n"                        

                        # rpi_conn.sendall(motor_command)
                        # print(f"send motor_command {motor_command}")

                    # 화면에 디버그용으로 표시
                    lane_overlay = np.zeros_like(undist_frame)
                    lane_overlay[preprocessImage == 255] = [0, 0, 255]
                    combined = cv2.addWeighted(undist_frame, 0.7, lane_overlay, 1.0, 0)
                    cv2.imshow("Lane Detection", combined)

                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        break
                else:
                    print("Error: Unable to decode frame")

            # status data
            elif header == b'CS':
                status_data = b''
                while len(status_data) < 1:
                    packet = rpi_conn.recv(1 - len(status_data))
                    if not packet:
                        break
                    status_data += packet

                rpi_conn.recv(1)  # \n 받기

                status = int.from_bytes(status_data, byteorder="big")
                if status == 1:
                    print("status:", status)
                else:
                    print("status", status)

    except Exception as e:
        print(f"Error receiving or displaying frame: {e}")

    finally:
        rpi_conn.close()
        cv2.destroyAllWindows()

def send_motor_value(rpi_conn):
    global left_speed, right_speed
    while True:
        start = 60
        motor_command = start.to_bytes(1, byteorder="big") + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n" 

        try:
            rpi_conn.sendall(motor_command)
            print(f"send motor_command {motor_command}")
        except Exception as e:
            print(f"Error sending motor command: {e}")
        
        time.sleep(1)  # 2~5초에 한번 쏴주는것만으로도 충분함. 타임 슬립없으면 충돌남.

def flower_detect_information(pollination_conn):
    try:
        while True:
            header = b''
            while len(header) < 1:
                header += pollination_conn.recv(1 - len(header))

            # detect data
            if int.from_bytes(header, byteorder="big") == 22:
                size_data = b''
                print("get in header pollination")
                while len(size_data) < 2:
                    packet = pollination_conn.recv(2 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                data_size = int.from_bytes(size_data, byteorder="big")
                
                detect_data = b''
                while len(detect_data) < data_size:
                    packet = pollination_conn.recv(data_size - len(detect_data))
                    if not packet:
                        break
                    detect_data += packet

                pollination_conn.recv(1)  # \n 받기
                
                before_idx = 0
                for i in range(10, data_size, 10):
                    data = detect_data[before_idx : i]
                    before_idx = i
                    class_id = int.from_bytes(data[:2], byteorder="big")
                    x1 = int.from_bytes(data[2:4], byteorder="big")
                    y1 = int.from_bytes(data[4:6], byteorder="big")
                    x2 =int.from_bytes(data[6:8], byteorder="big")
                    y2 = int.from_bytes(data[8:], byteorder="big")
                    print(f"class : {class_id}, x1: {x1}, y1: {y1}, x2: {x2}, y2: {y2}")

    except Exception as e:
        print(f"Error receiving pollination data: {e}")
                

if __name__ == "__main__" :

    # 서버 설정
    server_ip = "192.168.0.134"
    rpi_server_port = 3141
    pollination_server_port = 8888

    rpi_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    rpi_server_socket.bind((server_ip, rpi_server_port))
    rpi_server_socket.listen(1)
    print(f"서버가 {server_ip} : {rpi_server_port}에서 대기 중입니다...")

    pollination_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    pollination_server_socket.bind((server_ip, pollination_server_port))
    pollination_server_socket.listen(1)
    print(f"서버가 {server_ip} : {pollination_server_port}에서 대기 중입니다...")

    rpi_conn, addr = rpi_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")
    
    pollination_conn, addr = pollination_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    client_thread = Thread(target=handle_client, args=(rpi_conn,))
    client_thread.start()

    motor_cmd_thread = Thread(target=send_motor_value, args=(rpi_conn,))
    motor_cmd_thread.start()

    pollination_thread = Thread(target=flower_detect_information, args=(pollination_conn,))
    pollination_thread.start()

    client_thread.join()
    motor_cmd_thread.join()
    pollination_thread.join()

    rpi_conn.close()
    rpi_server_socket.close()
    pollination_conn.close()
    pollination_server_socket.close()
    cv2.destroyAllWindows()
# Out:
# 서버가 192.168.0.134 : 3141에서 대기 중입니다...
# 서버가 192.168.0.134 : 8888에서 대기 중입니다...
# 클라이언트 ('192.168.0.25', 53506)와 연결되었습니다.
# 클라이언트 ('192.168.0.44', 59608)와 연결되었습니다.
# send motor_command b'<\x00\x00\n'
# status: 1
# send motor_command b'<6-\n'
# get in header pollination
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 359, x2: 162, y2: 547
# class : 0, x1: 0, y1: 0, x2: 31, y2: 46
# class : 0, x1: 37, y1: 429, x2: 86, y2: 486
# class : 2, x1: 132, y1: 416, x2: 276, y2: 577
# class : 2, x1: 0, y1: 559, x2: 114, y2: 639
# get in header pollination
# class : 2, x1: 0, y1: 359, x2: 162, y2: 546
# class : 2, x1: 131, y1: 415, x2: 275, y2: 577
# class : 0, x1: 0, y1: 0, x2: 31, y2: 46
# send motor_command b'<6-\n'
# get in header pollination
# class : 2, x1: 0, y1: 359, x2: 161, y2: 548
# class : 2, x1: 132, y1: 415, x2: 276, y2: 577
# class : 2, x1: 0, y1: 558, x2: 117, y2: 640
# get in header pollination
# class : 2, x1: 0, y1: 359, x2: 162, y2: 547
# class : 2, x1: 0, y1: 560, x2: 115, y2: 639
# class : 2, x1: 132, y1: 415, x2: 276, y2: 577
# get in header pollination
# class : 2, x1: 0, y1: 359, x2: 162, y2: 546
# class : 2, x1: 133, y1: 416, x2: 276, y2: 577
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 358, x2: 162, y2: 546
# class : 2, x1: 133, y1: 415, x2: 275, y2: 578
# class : 0, x1: 38, y1: 430, x2: 85, y2: 486
# get in header pollination
# class : 2, x1: 0, y1: 358, x2: 162, y2: 547
# class : 2, x1: 134, y1: 415, x2: 275, y2: 577
# class : 0, x1: 39, y1: 430, x2: 85, y2: 485
# get in header pollination
# class : 2, x1: 0, y1: 358, x2: 163, y2: 546
# class : 0, x1: 37, y1: 430, x2: 85, y2: 484
# class : 2, x1: 132, y1: 416, x2: 275, y2: 577
# class : 0, x1: 0, y1: 0, x2: 30, y2: 46
# send motor_command b'<7-\n'
# status: 1
# get in header pollination
# class : 2, x1: 0, y1: 358, x2: 162, y2: 546
# class : 0, x1: 0, y1: 0, x2: 33, y2: 49
# class : 0, x1: 37, y1: 430, x2: 87, y2: 487
# get in header pollination
# class : 2, x1: 0, y1: 358, x2: 163, y2: 547
# class : 2, x1: 108, y1: 201, x2: 234, y2: 314
# class : 0, x1: 38, y1: 429, x2: 83, y2: 480
# get in header pollination
# class : 2, x1: 0, y1: 358, x2: 162, y2: 545
# class : 0, x1: 0, y1: 0, x2: 34, y2: 51
# class : 0, x1: 38, y1: 430, x2: 84, y2: 483
# class : 2, x1: 109, y1: 201, x2: 232, y2: 313
# class : 2, x1: 133, y1: 417, x2: 274, y2: 578
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 358, x2: 161, y2: 545
# class : 0, x1: 0, y1: 0, x2: 33, y2: 50
# class : 0, x1: 39, y1: 429, x2: 84, y2: 482
# class : 0, x1: 20, y1: 500, x2: 62, y2: 544
# get in header pollination
# class : 2, x1: 0, y1: 357, x2: 163, y2: 545
# class : 2, x1: 109, y1: 201, x2: 231, y2: 314
# class : 0, x1: 39, y1: 429, x2: 83, y2: 480
# class : 0, x1: 19, y1: 500, x2: 62, y2: 544
# get in header pollination
# class : 2, x1: 0, y1: 357, x2: 162, y2: 544
# class : 2, x1: 109, y1: 201, x2: 232, y2: 314
# class : 0, x1: 0, y1: 0, x2: 34, y2: 49
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 357, x2: 162, y2: 545
# class : 2, x1: 111, y1: 200, x2: 230, y2: 317
# class : 0, x1: 40, y1: 431, x2: 81, y2: 476
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 164, y2: 546
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 547
# class : 0, x1: 39, y1: 433, x2: 87, y2: 486
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 548
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 162, y2: 549
# class : 0, x1: 40, y1: 434, x2: 85, y2: 485
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 547
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 162, y2: 547
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 550
# class : 0, x1: 0, y1: 0, x2: 33, y2: 78
# class : 0, x1: 38, y1: 434, x2: 89, y2: 489
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 549
# class : 0, x1: 39, y1: 433, x2: 87, y2: 485
# class : 0, x1: 0, y1: 0, x2: 33, y2: 76
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 162, y2: 548
# class : 0, x1: 38, y1: 435, x2: 90, y2: 487
# send motor_command b'<6-\n'
# status: 1
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 553
# class : 0, x1: 0, y1: 0, x2: 33, y2: 79
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 162, y2: 546
# class : 0, x1: 38, y1: 434, x2: 87, y2: 485
# class : 1, x1: 34, y1: 281, x2: 106, y2: 349
# get in header pollination
# send motor_command b'<7,\n'
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 547
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 546
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 162, y2: 548
# class : 0, x1: 0, y1: 0, x2: 32, y2: 76
# send motor_command b'<7,\n'
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 162, y2: 547
# class : 0, x1: 0, y1: 0, x2: 34, y2: 77
# class : 0, x1: 38, y1: 434, x2: 90, y2: 490
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 162, y2: 547
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 162, y2: 549
# class : 0, x1: 0, y1: 0, x2: 33, y2: 77
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 550
# class : 0, x1: 0, y1: 0, x2: 33, y2: 74
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 547
# class : 1, x1: 29, y1: 280, x2: 106, y2: 350
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 548
# send motor_command b'<7-\n'
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 549
# class : 0, x1: 0, y1: 0, x2: 33, y2: 78
# get in header pollination
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 549
# class : 0, x1: 39, y1: 433, x2: 89, y2: 487
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 162, y2: 545
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 548
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 164, y2: 548
# class : 0, x1: 0, y1: 0, x2: 33, y2: 78
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 547
# class : 0, x1: 0, y1: 0, x2: 32, y2: 76
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 549
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 546
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 548
# class : 0, x1: 38, y1: 434, x2: 90, y2: 486
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 550
# class : 1, x1: 33, y1: 283, x2: 107, y2: 351
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 547
# class : 0, x1: 38, y1: 434, x2: 92, y2: 489
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 554
# class : 2, x1: 108, y1: 205, x2: 225, y2: 318
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 549
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 164, y2: 547
# class : 0, x1: 37, y1: 434, x2: 90, y2: 491
# class : 0, x1: 0, y1: 0, x2: 33, y2: 76
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 547
# class : 0, x1: 0, y1: 0, x2: 33, y2: 75
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 547
# class : 0, x1: 38, y1: 433, x2: 90, y2: 491
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 164, y2: 554
# class : 1, x1: 36, y1: 281, x2: 106, y2: 351
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 164, y2: 549
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 164, y2: 548
# class : 0, x1: 37, y1: 433, x2: 91, y2: 491
# class : 2, x1: 108, y1: 207, x2: 227, y2: 317
# class : 0, x1: 0, y1: 0, x2: 33, y2: 79
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 550
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 550
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 548
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 164, y2: 548
# get in header pollination
# class : 2, x1: 0, y1: 365, x2: 163, y2: 548
# get in header pollination
# class : 2, x1: 0, y1: 364, x2: 163, y2: 548
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 316
#     313 pollination_thread = Thread(target=flower_detect_information, args=(pollination_conn,))
#     314 pollination_thread.start()
# --> 316 client_thread.join()
#     317 motor_cmd_thread.join()
#     318 pollination_thread.join()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe

# %% [markdown]
# ### 위에서 obstacle 서버 추가

# %%
import cv2
import numpy as np
import socket
import struct
import time
from threading import Thread

# Sobel 연산을 통한 x 또는 y 방향 경계 계산 함수
def abs_sobel_thresh(img, orient='x', thresh_min=25, thresh_max=255):
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS).astype(float)
    l_channel = hls[:, :, 1]

    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 1, 0))
    elif orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 0, 1))
    else:
        raise ValueError("orient must be 'x' or 'y'")

    scaled_sobel = np.uint8(255 * abs_sobel / np.max(abs_sobel))

    binary_output = np.zeros_like(scaled_sobel)
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

    return binary_output

# 색상 정보를 기반으로 특정 범위에 해당하는 색상을 강조하는 함수
def color_threshold(image, sthresh=(0, 255), vthresh=(0, 255)):
    hls = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
    s_channel = hls[:, :, 2]

    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= sthresh[0]) & (s_channel <= sthresh[1])] = 1

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    v_channel = hsv[:, :, 2]

    v_binary = np.zeros_like(v_channel)
    v_binary[(v_channel >= vthresh[0]) & (vthresh[1] >= v_channel)] = 1

    output = np.zeros_like(s_channel)
    output[(s_binary == 1) & (v_binary == 1)] = 1

    return output

# 이미지의 특정 영역(ROI)을 선택하는 함수
def apply_roi(image):
    height = image.shape[0]
    mask = np.zeros_like(image)

    polygon = np.array([[
        (0, int(height * 2/5)),
        (image.shape[1], int(height * 2/5)),
        (image.shape[1], height),
        (0, height)
    ]], np.int32)

    cv2.fillPoly(mask, polygon, 255)
    roi_image = cv2.bitwise_and(image, mask)
    return roi_image

# 카메라 매트릭스와 왜곡 계수
mtx = np.array([[1.15753008e+03, 0.00000000e+00, 6.75382833e+02],
                [0.00000000e+00, 1.15189955e+03, 3.86729350e+02],
                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])
dist = np.array([[-0.26706898,  0.10305542, -0.00088013,  0.00080643, -0.19574027]])

left_speed = 0
right_speed = 0

def handle_client(rpi_conn, obs_conn):
    global left_speed, right_speed
    try:
        while True:
            header = b''
            while len(header) < 2:
                header += rpi_conn.recv(2 - len(header))

            # frame data
            if header == b'SF':
                size_data = b''
                while len(size_data) < 4:
                    packet = rpi_conn.recv(4 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                frame_size = struct.unpack(">L", size_data)[0]

                frame_data = b''
                while len(frame_data) < frame_size:
                    packet = rpi_conn.recv(frame_size - len(frame_data))
                    if not packet:
                        break
                    frame_data += packet

                rpi_conn.recv(1)  # \n 받기

                frame = cv2.imdecode(np.frombuffer(frame_data, np.uint8), cv2.IMREAD_COLOR)

                if frame is not None:
                    # 카메라 캘리브레이션 적용
                    undist_frame = cv2.undistort(frame, mtx, dist, None, mtx)

                    # 캘리브레이션 적용 카메라 obstacle로 전송
                    _, buffer = cv2.imencode(".jpg", undist_frame)
                    obs_frame_data = buffer.tobytes()
                    obs_frame_size = len(obs_frame_data)
                    obs_header = b'SF'
                    obs_conn.sendall(obs_header + struct.pack(">L", obs_frame_size) + obs_frame_data + b'\n')
                    print(f"obs server로 크기 {obs_frame_size}의 프레임을 전송했습니다.")

                    # 차선 검출
                    gradx = abs_sobel_thresh(undist_frame, orient='x', thresh_min=20, thresh_max=100)
                    grady = abs_sobel_thresh(undist_frame, orient='y', thresh_min=20, thresh_max=100)

                    # 색상 임계값 적용
                    c_binary = color_threshold(undist_frame, sthresh=(80, 255), vthresh=(50, 255))

                    # 최종 이진 이미지 생성
                    preprocessImage = np.zeros_like(undist_frame[:, :, 0])
                    preprocessImage[((gradx == 1) & (grady == 1)) | (c_binary == 1)] = 255

                    # ROI 적용
                    preprocessImage = apply_roi(preprocessImage)

                    # 무게 중심을 기반으로 모터 제어
                    midpoint = preprocessImage.shape[1] // 2

                    nonzero = preprocessImage.nonzero()
                    nonzeroy = np.array(nonzero[0])
                    nonzerox = np.array(nonzero[1])

                    left_lane_inds = (nonzerox < midpoint)
                    right_lane_inds = (nonzerox >= midpoint)

                    leftx = nonzerox[left_lane_inds]
                    lefty = nonzeroy[left_lane_inds]
                    rightx = nonzerox[right_lane_inds]
                    righty = nonzeroy[right_lane_inds]

                    # 왼쪽 차선의 무게중심 계산 및 표시
                    if len(leftx) > 0 and len(lefty) > 0:
                        left_center_x = int(np.mean(leftx))
                        left_center_y = int(np.mean(lefty))
                        cv2.circle(undist_frame, (left_center_x, left_center_y), 5, (0, 255, 0), -1)
                    else:
                        left_center_x = None
                        left_center_y = None

                    # 오른쪽 차선의 무게중심 계산 및 표시
                    if len(rightx) > 0 and len(righty) > 0:
                        right_center_x = int(np.mean(rightx))
                        right_center_y = int(np.mean(righty))
                        cv2.circle(undist_frame, (right_center_x, right_center_y), 5, (0, 255, 0), -1)
                    else:
                        right_center_x = None
                        right_center_y = None

                    # 두 차선 무게중심의 중앙점 계산 및 표시
                    if left_center_x is not None and right_center_x is not None:
                        mid_center_x = int((left_center_x + right_center_x) / 2)
                        mid_center_y = int((left_center_y + right_center_y) / 2)
                        cv2.circle(undist_frame, (mid_center_x, mid_center_y), 5, (255, 0, 0), -1)

                        # 이미지 중앙과의 편차 계산
                        image_center_x = undist_frame.shape[1] // 2
                        deviation = mid_center_x - image_center_x

                        # 모터 값 계산 및 전송
                        max_speed = 100  # 최대 속도
                        base_speed = 50  # 기본 속도
                        max_deviation = undist_frame.shape[1] // 2

                        normalized_deviation = deviation / max_deviation
                        normalized_deviation = np.clip(normalized_deviation, -1, 1)

                        left_speed = base_speed - (normalized_deviation * base_speed)
                        right_speed = base_speed + (normalized_deviation * base_speed)

                        left_speed = int(np.clip(left_speed, 0, max_speed))
                        right_speed = int(np.clip(right_speed, 0, max_speed))
                        
                        
                        # # 수정된 코드:
                        # command_id = 'M'

                        # motor_command = struct.pack('2shh', command_id.encode('utf-8'), left_speed, right_speed)
                        # motor_command += b'\n'
                        # print(f"Sending motor command: {command_id} with speeds L: {left_speed}, R: {right_speed}")

                        #motor_command = b'M' + bytes([left_speed, right_speed]) + b'\n'
                        
                        # motor_command = bytes([10, left_speed, right_speed]) + b'\n'
                        # motor_command = b'M' + b'R' if deviation > 0 else b'L' + right_speed.to_bytes(2, byteorder="big") + b'\n'

                        # motor_command = b"M" + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n"                        

                        # rpi_conn.sendall(motor_command)
                        # print(f"send motor_command {motor_command}")

                    # 화면에 디버그용으로 표시
                    lane_overlay = np.zeros_like(undist_frame)
                    lane_overlay[preprocessImage == 255] = [0, 0, 255]
                    combined = cv2.addWeighted(undist_frame, 0.7, lane_overlay, 1.0, 0)
                    cv2.imshow("Lane Detection", combined)

                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        break
                else:
                    print("Error: Unable to decode frame")

            # status data
            elif header == b'CS':
                status_data = b''
                while len(status_data) < 1:
                    packet = rpi_conn.recv(1 - len(status_data))
                    if not packet:
                        break
                    status_data += packet

                rpi_conn.recv(1)  # \n 받기

                status = int.from_bytes(status_data, byteorder="big")
                if status == 1:
                    print("status:", status)
                else:
                    print("status", status)

    except Exception as e:
        print(f"Error receiving or displaying frame: {e}")

    finally:
        rpi_conn.close()
        cv2.destroyAllWindows()

def send_motor_value(rpi_conn):
    global left_speed, right_speed
    while True:
        start = b'MC'
        motor_command = start + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n" 

        try:
            rpi_conn.sendall(motor_command)
            print(f"send motor_command {motor_command}")
        except Exception as e:
            print(f"Error sending motor command: {e}")
        
        time.sleep(2)  # 2~5초에 한번 쏴주는것만으로도 충분함. 타임 슬립없으면 충돌남.

def flower_detect_information(pollination_conn):
    try:
        while True:
            header = b''
            while len(header) < 1:
                header += pollination_conn.recv(1 - len(header))

            # detect data
            if int.from_bytes(header, byteorder="big") == 22:
                size_data = b''
                print("get in header pollination")
                while len(size_data) < 2:
                    packet = pollination_conn.recv(2 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                data_size = int.from_bytes(size_data, byteorder="big")
                
                detect_data = b''
                while len(detect_data) < data_size:
                    packet = pollination_conn.recv(data_size - len(detect_data))
                    if not packet:
                        break
                    detect_data += packet

                pollination_conn.recv(1)  # \n 받기
                
                before_idx = 0
                for i in range(10, data_size, 10):
                    data = detect_data[before_idx : i]
                    before_idx = i
                    class_id = int.from_bytes(data[:2], byteorder="big")
                    x1 = int.from_bytes(data[2:4], byteorder="big")
                    y1 = int.from_bytes(data[4:6], byteorder="big")
                    x2 =int.from_bytes(data[6:8], byteorder="big")
                    y2 = int.from_bytes(data[8:], byteorder="big")
                    print(f"class : {class_id}, x1: {x1}, y1: {y1}, x2: {x2}, y2: {y2}")

    except Exception as e:
        print(f"Error receiving pollination data: {e}")
                

if __name__ == "__main__" :

    # 서버 설정
    server_ip = "192.168.0.134"
    rpi_server_port = 3141
    pollination_server_port = 8888
    obs_server_port = 4040

    rpi_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    rpi_server_socket.bind((server_ip, rpi_server_port))
    rpi_server_socket.listen(1)
    print(f"서버가 {server_ip} : {rpi_server_port}에서 대기 중입니다...")

    obs_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    obs_server_socket.bind((server_ip, obs_server_port))
    obs_server_socket.listen(1)
    print(f"서버가 {server_ip} : {obs_server_port}에서 대기 중입니다...")

    pollination_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    pollination_server_socket.bind((server_ip, pollination_server_port))
    pollination_server_socket.listen(1)
    print(f"서버가 {server_ip} : {pollination_server_port}에서 대기 중입니다...")

    rpi_conn, addr = rpi_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    obs_conn, addr = obs_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    pollination_conn, addr = pollination_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    client_thread = Thread(target=handle_client, args=(rpi_conn, obs_conn))
    client_thread.start()

    motor_cmd_thread = Thread(target=send_motor_value, args=(rpi_conn,))
    motor_cmd_thread.start()

    pollination_thread = Thread(target=flower_detect_information, args=(pollination_conn,))
    pollination_thread.start()

    client_thread.join()
    motor_cmd_thread.join()
    pollination_thread.join()

    rpi_conn.close()
    rpi_server_socket.close()
    pollination_conn.close()
    pollination_server_socket.close()
    cv2.destroyAllWindows()
# Out:
# 서버가 192.168.0.134 : 3141에서 대기 중입니다...
# 서버가 192.168.0.134 : 4040에서 대기 중입니다...
# 서버가 192.168.0.134 : 8888에서 대기 중입니다...
# 클라이언트 ('192.168.0.25', 47740)와 연결되었습니다.
# 클라이언트 ('192.168.0.147', 33348)와 연결되었습니다.
# 클라이언트 ('192.168.0.44', 60178)와 연결되었습니다.
# send motor_command b'MC\x00\x00\n'
# status: 1
# obs server로 크기 61668의 프레임을 전송했습니다.
# obs server로 크기 61522의 프레임을 전송했습니다.
# obs server로 크기 61553의 프레임을 전송했습니다.
# obs server로 크기 61594의 프레임을 전송했습니다.
# obs server로 크기 61499의 프레임을 전송했습니다.
# obs server로 크기 61467의 프레임을 전송했습니다.
# obs server로 크기 61576의 프레임을 전송했습니다.
# obs server로 크기 61618의 프레임을 전송했습니다.
# obs server로 크기 61537의 프레임을 전송했습니다.
# get in header pollination
# send motor_command b"MC'<\n"
# obs server로 크기 61595의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61636의 프레임을 전송했습니다.
# obs server로 크기 61668의 프레임을 전송했습니다.
# obs server로 크기 61428의 프레임을 전송했습니다.
# obs server로 크기 61586의 프레임을 전송했습니다.
# obs server로 크기 61628의 프레임을 전송했습니다.
# obs server로 크기 61600의 프레임을 전송했습니다.
# obs server로 크기 61684의 프레임을 전송했습니다.
# obs server로 크기 61738의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61598의 프레임을 전송했습니다.
# obs server로 크기 61616의 프레임을 전송했습니다.
# obs server로 크기 61591의 프레임을 전송했습니다.
# obs server로 크기 61723의 프레임을 전송했습니다.
# obs server로 크기 61651의 프레임을 전송했습니다.
# obs server로 크기 61620의 프레임을 전송했습니다.
# obs server로 크기 61613의 프레임을 전송했습니다.
# obs server로 크기 61671의 프레임을 전송했습니다.
# obs server로 크기 61732의 프레임을 전송했습니다.
# obs server로 크기 61611의 프레임을 전송했습니다.
# obs server로 크기 61671의 프레임을 전송했습니다.
# obs server로 크기 61557의 프레임을 전송했습니다.
# obs server로 크기 61705의 프레임을 전송했습니다.
# obs server로 크기 61585의 프레임을 전송했습니다.
# obs server로 크기 61636의 프레임을 전송했습니다.
# obs server로 크기 61629의 프레임을 전송했습니다.
# obs server로 크기 61617의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61464의 프레임을 전송했습니다.
# obs server로 크기 61625의 프레임을 전송했습니다.
# obs server로 크기 61657의 프레임을 전송했습니다.
# obs server로 크기 61647의 프레임을 전송했습니다.
# obs server로 크기 61717의 프레임을 전송했습니다.
# obs server로 크기 61670의 프레임을 전송했습니다.
# obs server로 크기 61610의 프레임을 전송했습니다.
# obs server로 크기 61540의 프레임을 전송했습니다.
# obs server로 크기 61658의 프레임을 전송했습니다.
# obs server로 크기 61590의 프레임을 전송했습니다.
# obs server로 크기 61729의 프레임을 전송했습니다.
# obs server로 크기 61850의 프레임을 전송했습니다.
# obs server로 크기 61596의 프레임을 전송했습니다.
# obs server로 크기 61576의 프레임을 전송했습니다.
# obs server로 크기 61533의 프레임을 전송했습니다.
# obs server로 크기 61745의 프레임을 전송했습니다.
# obs server로 크기 61554의 프레임을 전송했습니다.
# obs server로 크기 61488의 프레임을 전송했습니다.
# obs server로 크기 61524의 프레임을 전송했습니다.
# obs server로 크기 61588의 프레임을 전송했습니다.
# obs server로 크기 61606의 프레임을 전송했습니다.
# obs server로 크기 61616의 프레임을 전송했습니다.
# obs server로 크기 61778의 프레임을 전송했습니다.
# obs server로 크기 61789의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61798의 프레임을 전송했습니다.
# obs server로 크기 61814의 프레임을 전송했습니다.
# obs server로 크기 61805의 프레임을 전송했습니다.
# obs server로 크기 61874의 프레임을 전송했습니다.
# obs server로 크기 61820의 프레임을 전송했습니다.
# obs server로 크기 61812의 프레임을 전송했습니다.
# obs server로 크기 61790의 프레임을 전송했습니다.
# obs server로 크기 61747의 프레임을 전송했습니다.
# obs server로 크기 61568의 프레임을 전송했습니다.
# obs server로 크기 61696의 프레임을 전송했습니다.
# send motor_command b"MC'<\n"
# obs server로 크기 61722의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61564의 프레임을 전송했습니다.
# obs server로 크기 61616의 프레임을 전송했습니다.
# obs server로 크기 61675의 프레임을 전송했습니다.
# obs server로 크기 61616의 프레임을 전송했습니다.
# obs server로 크기 61613의 프레임을 전송했습니다.
# obs server로 크기 61574의 프레임을 전송했습니다.
# obs server로 크기 61631의 프레임을 전송했습니다.
# obs server로 크기 61539의 프레임을 전송했습니다.
# obs server로 크기 61669의 프레임을 전송했습니다.
# obs server로 크기 61701의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61555의 프레임을 전송했습니다.
# obs server로 크기 61451의 프레임을 전송했습니다.
# obs server로 크기 61700의 프레임을 전송했습니다.
# obs server로 크기 61441의 프레임을 전송했습니다.
# obs server로 크기 61539의 프레임을 전송했습니다.
# obs server로 크기 61674의 프레임을 전송했습니다.
# obs server로 크기 61677의 프레임을 전송했습니다.
# get in header pollination
# class : 0, x1: 294, y1: 0, x2: 480, y2: 142
# obs server로 크기 61627의 프레임을 전송했습니다.
# obs server로 크기 61695의 프레임을 전송했습니다.
# obs server로 크기 61649의 프레임을 전송했습니다.
# obs server로 크기 61630의 프레임을 전송했습니다.
# obs server로 크기 61575의 프레임을 전송했습니다.
# obs server로 크기 61798의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 345
# obs server로 크기 61581의 프레임을 전송했습니다.
# obs server로 크기 61518의 프레임을 전송했습니다.
# obs server로 크기 61490의 프레임을 전송했습니다.
# obs server로 크기 61529의 프레임을 전송했습니다.
# obs server로 크기 61626의 프레임을 전송했습니다.
# status: 1
# obs server로 크기 61516의 프레임을 전송했습니다.
# obs server로 크기 61499의 프레임을 전송했습니다.
# obs server로 크기 61509의 프레임을 전송했습니다.
# obs server로 크기 61444의 프레임을 전송했습니다.
# obs server로 크기 61435의 프레임을 전송했습니다.
# obs server로 크기 61388의 프레임을 전송했습니다.
# obs server로 크기 61694의 프레임을 전송했습니다.
# obs server로 크기 61712의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 344
# obs server로 크기 61641의 프레임을 전송했습니다.
# obs server로 크기 61651의 프레임을 전송했습니다.
# obs server로 크기 61573의 프레임을 전송했습니다.
# obs server로 크기 61713의 프레임을 전송했습니다.
# obs server로 크기 61678의 프레임을 전송했습니다.
# obs server로 크기 61587의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61523의 프레임을 전송했습니다.
# obs server로 크기 61509의 프레임을 전송했습니다.
# obs server로 크기 61501의 프레임을 전송했습니다.
# obs server로 크기 61527의 프레임을 전송했습니다.
# obs server로 크기 61810의 프레임을 전송했습니다.
# obs server로 크기 61620의 프레임을 전송했습니다.
# send motor_command b"MC'<\n"
# obs server로 크기 61459의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 345
# obs server로 크기 61483의 프레임을 전송했습니다.
# obs server로 크기 61581의 프레임을 전송했습니다.
# obs server로 크기 61633의 프레임을 전송했습니다.
# obs server로 크기 61676의 프레임을 전송했습니다.
# obs server로 크기 61560의 프레임을 전송했습니다.
# obs server로 크기 61478의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 346
# obs server로 크기 61657의 프레임을 전송했습니다.
# obs server로 크기 61652의 프레임을 전송했습니다.
# obs server로 크기 61631의 프레임을 전송했습니다.
# obs server로 크기 61602의 프레임을 전송했습니다.
# obs server로 크기 61623의 프레임을 전송했습니다.
# obs server로 크기 61689의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 61715의 프레임을 전송했습니다.
# obs server로 크기 61666의 프레임을 전송했습니다.
# obs server로 크기 61787의 프레임을 전송했습니다.
# obs server로 크기 61791의 프레임을 전송했습니다.
# obs server로 크기 61626의 프레임을 전송했습니다.
# obs server로 크기 61726의 프레임을 전송했습니다.
# obs server로 크기 61736의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 333, y2: 345
# obs server로 크기 61491의 프레임을 전송했습니다.
# obs server로 크기 61679의 프레임을 전송했습니다.
# obs server로 크기 61527의 프레임을 전송했습니다.
# obs server로 크기 61735의 프레임을 전송했습니다.
# obs server로 크기 61633의 프레임을 전송했습니다.
# obs server로 크기 61597의 프레임을 전송했습니다.
# obs server로 크기 61380의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 345
# obs server로 크기 61531의 프레임을 전송했습니다.
# obs server로 크기 61549의 프레임을 전송했습니다.
# obs server로 크기 61513의 프레임을 전송했습니다.
# obs server로 크기 61465의 프레임을 전송했습니다.
# obs server로 크기 61511의 프레임을 전송했습니다.
# obs server로 크기 61585의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61561의 프레임을 전송했습니다.
# obs server로 크기 61402의 프레임을 전송했습니다.
# obs server로 크기 61550의 프레임을 전송했습니다.
# obs server로 크기 61525의 프레임을 전송했습니다.
# obs server로 크기 61483의 프레임을 전송했습니다.
# obs server로 크기 61658의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# obs server로 크기 61494의 프레임을 전송했습니다.
# obs server로 크기 61444의 프레임을 전송했습니다.
# obs server로 크기 61764의 프레임을 전송했습니다.
# obs server로 크기 61521의 프레임을 전송했습니다.
# obs server로 크기 61338의 프레임을 전송했습니다.
# send motor_command b"MC'<\n"
# obs server로 크기 61553의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 308, y1: 309, x2: 332, y2: 346
# obs server로 크기 61460의 프레임을 전송했습니다.
# obs server로 크기 61618의 프레임을 전송했습니다.
# obs server로 크기 61657의 프레임을 전송했습니다.
# obs server로 크기 61598의 프레임을 전송했습니다.
# obs server로 크기 61495의 프레임을 전송했습니다.
# obs server로 크기 61385의 프레임을 전송했습니다.
# obs server로 크기 61306의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 61264의 프레임을 전송했습니다.
# obs server로 크기 61247의 프레임을 전송했습니다.
# obs server로 크기 60909의 프레임을 전송했습니다.
# obs server로 크기 60743의 프레임을 전송했습니다.
# obs server로 크기 60666의 프레임을 전송했습니다.
# obs server로 크기 60507의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 60731의 프레임을 전송했습니다.
# obs server로 크기 61355의 프레임을 전송했습니다.
# obs server로 크기 61410의 프레임을 전송했습니다.
# obs server로 크기 61231의 프레임을 전송했습니다.
# obs server로 크기 60781의 프레임을 전송했습니다.
# obs server로 크기 60710의 프레임을 전송했습니다.
# obs server로 크기 60363의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# obs server로 크기 60710의 프레임을 전송했습니다.
# obs server로 크기 60577의 프레임을 전송했습니다.
# obs server로 크기 60641의 프레임을 전송했습니다.
# obs server로 크기 60670의 프레임을 전송했습니다.
# obs server로 크기 61029의 프레임을 전송했습니다.
# obs server로 크기 60775의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 345
# obs server로 크기 60737의 프레임을 전송했습니다.
# obs server로 크기 60656의 프레임을 전송했습니다.
# obs server로 크기 60768의 프레임을 전송했습니다.
# obs server로 크기 60688의 프레임을 전송했습니다.
# obs server로 크기 60645의 프레임을 전송했습니다.
# obs server로 크기 60631의 프레임을 전송했습니다.
# obs server로 크기 60600의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 60881의 프레임을 전송했습니다.
# obs server로 크기 60769의 프레임을 전송했습니다.
# obs server로 크기 60950의 프레임을 전송했습니다.
# obs server로 크기 60775의 프레임을 전송했습니다.
# obs server로 크기 60468의 프레임을 전송했습니다.
# obs server로 크기 60638의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 347
# obs server로 크기 60705의 프레임을 전송했습니다.
# obs server로 크기 60647의 프레임을 전송했습니다.
# obs server로 크기 60639의 프레임을 전송했습니다.
# obs server로 크기 60689의 프레임을 전송했습니다.
# obs server로 크기 60747의 프레임을 전송했습니다.
# obs server로 크기 60852의 프레임을 전송했습니다.
# send motor_command b"MC'<\n"
# obs server로 크기 60956의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 60658의 프레임을 전송했습니다.
# status: 1
# obs server로 크기 60792의 프레임을 전송했습니다.
# obs server로 크기 61072의 프레임을 전송했습니다.
# obs server로 크기 61323의 프레임을 전송했습니다.
# obs server로 크기 61491의 프레임을 전송했습니다.
# obs server로 크기 61768의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 61593의 프레임을 전송했습니다.
# obs server로 크기 61361의 프레임을 전송했습니다.
# obs server로 크기 61293의 프레임을 전송했습니다.
# obs server로 크기 61122의 프레임을 전송했습니다.
# obs server로 크기 61320의 프레임을 전송했습니다.
# obs server로 크기 61411의 프레임을 전송했습니다.
# obs server로 크기 61481의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 346
# obs server로 크기 61473의 프레임을 전송했습니다.
# obs server로 크기 61419의 프레임을 전송했습니다.
# obs server로 크기 61570의 프레임을 전송했습니다.
# obs server로 크기 61534의 프레임을 전송했습니다.
# obs server로 크기 61434의 프레임을 전송했습니다.
# obs server로 크기 61238의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 61304의 프레임을 전송했습니다.
# obs server로 크기 61538의 프레임을 전송했습니다.
# obs server로 크기 61608의 프레임을 전송했습니다.
# obs server로 크기 61502의 프레임을 전송했습니다.
# obs server로 크기 61535의 프레임을 전송했습니다.
# obs server로 크기 61470의 프레임을 전송했습니다.
# obs server로 크기 61446의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61664의 프레임을 전송했습니다.
# obs server로 크기 61773의 프레임을 전송했습니다.
# obs server로 크기 61713의 프레임을 전송했습니다.
# obs server로 크기 61770의 프레임을 전송했습니다.
# obs server로 크기 61675의 프레임을 전송했습니다.
# obs server로 크기 61745의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61775의 프레임을 전송했습니다.
# obs server로 크기 61766의 프레임을 전송했습니다.
# obs server로 크기 61810의 프레임을 전송했습니다.
# obs server로 크기 61706의 프레임을 전송했습니다.
# obs server로 크기 61602의 프레임을 전송했습니다.
# obs server로 크기 61603의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 61545의 프레임을 전송했습니다.
# obs server로 크기 61546의 프레임을 전송했습니다.
# obs server로 크기 61630의 프레임을 전송했습니다.
# obs server로 크기 61593의 프레임을 전송했습니다.
# obs server로 크기 61596의 프레임을 전송했습니다.
# send motor_command b"MC'<\n"
# obs server로 크기 61346의 프레임을 전송했습니다.
# obs server로 크기 61436의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# obs server로 크기 61188의 프레임을 전송했습니다.
# obs server로 크기 61365의 프레임을 전송했습니다.
# obs server로 크기 61189의 프레임을 전송했습니다.
# obs server로 크기 61425의 프레임을 전송했습니다.
# obs server로 크기 61229의 프레임을 전송했습니다.
# obs server로 크기 61163의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# obs server로 크기 61191의 프레임을 전송했습니다.
# obs server로 크기 61346의 프레임을 전송했습니다.
# obs server로 크기 61449의 프레임을 전송했습니다.
# obs server로 크기 61494의 프레임을 전송했습니다.
# obs server로 크기 61404의 프레임을 전송했습니다.
# obs server로 크기 61147의 프레임을 전송했습니다.
# obs server로 크기 61139의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 346
# obs server로 크기 61202의 프레임을 전송했습니다.
# obs server로 크기 61207의 프레임을 전송했습니다.
# obs server로 크기 61291의 프레임을 전송했습니다.
# obs server로 크기 61080의 프레임을 전송했습니다.
# obs server로 크기 61073의 프레임을 전송했습니다.
# obs server로 크기 60989의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 61115의 프레임을 전송했습니다.
# obs server로 크기 61240의 프레임을 전송했습니다.
# obs server로 크기 61259의 프레임을 전송했습니다.
# obs server로 크기 61106의 프레임을 전송했습니다.
# obs server로 크기 61333의 프레임을 전송했습니다.
# obs server로 크기 61125의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 61204의 프레임을 전송했습니다.
# obs server로 크기 61157의 프레임을 전송했습니다.
# obs server로 크기 61017의 프레임을 전송했습니다.
# obs server로 크기 61093의 프레임을 전송했습니다.
# obs server로 크기 60883의 프레임을 전송했습니다.
# obs server로 크기 60871의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 346
# class : 0, x1: 181, y1: 377, x2: 199, y2: 394
# obs server로 크기 60898의 프레임을 전송했습니다.
# obs server로 크기 60867의 프레임을 전송했습니다.
# obs server로 크기 60895의 프레임을 전송했습니다.
# obs server로 크기 60806의 프레임을 전송했습니다.
# obs server로 크기 60773의 프레임을 전송했습니다.
# obs server로 크기 60654의 프레임을 전송했습니다.
# obs server로 크기 60697의 프레임을 전송했습니다.
# get in header pollination
# obs server로 크기 60771의 프레임을 전송했습니다.
# obs server로 크기 60672의 프레임을 전송했습니다.
# obs server로 크기 60613의 프레임을 전송했습니다.
# obs server로 크기 60665의 프레임을 전송했습니다.
# send motor_command b"MC'<\n"
# obs server로 크기 60648의 프레임을 전송했습니다.
# obs server로 크기 60737의 프레임을 전송했습니다.
# get in header pollination
# class : 0, x1: 298, y1: 0, x2: 480, y2: 141
# obs server로 크기 60958의 프레임을 전송했습니다.
# obs server로 크기 60742의 프레임을 전송했습니다.
# obs server로 크기 60746의 프레임을 전송했습니다.
# obs server로 크기 60433의 프레임을 전송했습니다.
# obs server로 크기 60491의 프레임을 전송했습니다.
# obs server로 크기 60554의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# obs server로 크기 60246의 프레임을 전송했습니다.
# obs server로 크기 60245의 프레임을 전송했습니다.
# obs server로 크기 60417의 프레임을 전송했습니다.
# obs server로 크기 60560의 프레임을 전송했습니다.
# obs server로 크기 61088의 프레임을 전송했습니다.
# obs server로 크기 61044의 프레임을 전송했습니다.
# obs server로 크기 60968의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# obs server로 크기 61320의 프레임을 전송했습니다.
# obs server로 크기 61214의 프레임을 전송했습니다.
# obs server로 크기 61090의 프레임을 전송했습니다.
# obs server로 크기 61021의 프레임을 전송했습니다.
# obs server로 크기 61152의 프레임을 전송했습니다.
# obs server로 크기 61148의 프레임을 전송했습니다.
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# obs server로 크기 61196의 프레임을 전송했습니다.
# obs server로 크기 61002의 프레임을 전송했습니다.
# status: 1
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# send motor_command b"MC'<\n"
# get in header pollination
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 345
# get in header pollination
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 333, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 346
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 346
# get in header pollination
# class : 1, x1: 308, y1: 309, x2: 332, y2: 346
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 333, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 333, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 309, x2: 332, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 346
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# get in header pollination
# get in header pollination
# class : 1, x1: 308, y1: 308, x2: 333, y2: 346
# get in header pollination
# class : 1, x1: 309, y1: 310, x2: 332, y2: 345
# Error sending motor command: [Errno 32] Broken pipe
# get in header pollination
# get in header pollination
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# Error sending motor command: [Errno 32] Broken pipe
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### GUI 추가

# %%
import cv2
import numpy as np
import socket
import struct
import time
from threading import Thread
from concurrent.futures import ThreadPoolExecutor as executor

# Sobel 연산을 통한 x 또는 y 방향 경계 계산 함수
def abs_sobel_thresh(img, orient='x', thresh_min=25, thresh_max=255):
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS).astype(float)
    l_channel = hls[:, :, 1]

    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 1, 0))
    elif orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(l_channel, cv2.CV_64F, 0, 1))
    else:
        raise ValueError("orient must be 'x' or 'y'")

    scaled_sobel = np.uint8(255 * abs_sobel / np.max(abs_sobel))

    binary_output = np.zeros_like(scaled_sobel)
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

    return binary_output

# 색상 정보를 기반으로 특정 범위에 해당하는 색상을 강조하는 함수
def color_threshold(image, sthresh=(0, 255), vthresh=(0, 255)):
    hls = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
    s_channel = hls[:, :, 2]

    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= sthresh[0]) & (s_channel <= sthresh[1])] = 1

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    v_channel = hsv[:, :, 2]

    v_binary = np.zeros_like(v_channel)
    v_binary[(v_channel >= vthresh[0]) & (vthresh[1] >= v_channel)] = 1

    output = np.zeros_like(s_channel)
    output[(s_binary == 1) & (v_binary == 1)] = 1

    return output

# 이미지의 특정 영역(ROI)을 선택하는 함수
def apply_roi(image):
    height = image.shape[0]
    mask = np.zeros_like(image)

    polygon = np.array([[
        (0, int(height * 2/5)),
        (image.shape[1], int(height * 2/5)),
        (image.shape[1], height),
        (0, height)
    ]], np.int32)

    cv2.fillPoly(mask, polygon, 255)
    roi_image = cv2.bitwise_and(image, mask)
    return roi_image

# 카메라 매트릭스와 왜곡 계수
mtx = np.array([[1.15753008e+03, 0.00000000e+00, 6.75382833e+02],
                [0.00000000e+00, 1.15189955e+03, 3.86729350e+02],
                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])
dist = np.array([[-0.26706898,  0.10305542, -0.00088013,  0.00080643, -0.19574027]])

left_speed = 0
right_speed = 0
robot_state = 0

def handle_client(rpi_conn, obs_conn):
    global left_speed, right_speed, robot_state
    try:
        while True:
            if robot_state == 0:
                break
            header = b''
            while len(header) < 2:
                header += rpi_conn.recv(2 - len(header))

            # frame data
            if header == b'SF':
                size_data = b''
                while len(size_data) < 4:
                    packet = rpi_conn.recv(4 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                frame_size = struct.unpack(">L", size_data)[0]

                frame_data = b''
                while len(frame_data) < frame_size:
                    packet = rpi_conn.recv(frame_size - len(frame_data))
                    if not packet:
                        break
                    frame_data += packet

                rpi_conn.recv(1)  # \n 받기

                frame = cv2.imdecode(np.frombuffer(frame_data, np.uint8), cv2.IMREAD_COLOR)

                if frame is not None:
                    # 카메라 캘리브레이션 적용
                    undist_frame = cv2.undistort(frame, mtx, dist, None, mtx)

                    # 캘리브레이션 적용 카메라 obstacle로 전송
                    _, buffer = cv2.imencode(".jpg", undist_frame)
                    obs_frame_data = buffer.tobytes()
                    obs_frame_size = len(obs_frame_data)
                    obs_header = b'SF'
                    obs_conn.sendall(obs_header + struct.pack(">L", obs_frame_size) + obs_frame_data + b'\n')
                    print(f"obs server로 크기 {obs_frame_size}의 프레임을 전송했습니다.")

                    # 차선 검출
                    gradx = abs_sobel_thresh(undist_frame, orient='x', thresh_min=20, thresh_max=100)
                    grady = abs_sobel_thresh(undist_frame, orient='y', thresh_min=20, thresh_max=100)

                    # 색상 임계값 적용
                    c_binary = color_threshold(undist_frame, sthresh=(80, 255), vthresh=(50, 255))

                    # 최종 이진 이미지 생성
                    preprocessImage = np.zeros_like(undist_frame[:, :, 0])
                    preprocessImage[((gradx == 1) & (grady == 1)) | (c_binary == 1)] = 255

                    # ROI 적용
                    preprocessImage = apply_roi(preprocessImage)

                    # 무게 중심을 기반으로 모터 제어
                    midpoint = preprocessImage.shape[1] // 2

                    nonzero = preprocessImage.nonzero()
                    nonzeroy = np.array(nonzero[0])
                    nonzerox = np.array(nonzero[1])

                    left_lane_inds = (nonzerox < midpoint)
                    right_lane_inds = (nonzerox >= midpoint)

                    leftx = nonzerox[left_lane_inds]
                    lefty = nonzeroy[left_lane_inds]
                    rightx = nonzerox[right_lane_inds]
                    righty = nonzeroy[right_lane_inds]

                    # 왼쪽 차선의 무게중심 계산 및 표시
                    if len(leftx) > 0 and len(lefty) > 0:
                        left_center_x = int(np.mean(leftx))
                        left_center_y = int(np.mean(lefty))
                        cv2.circle(undist_frame, (left_center_x, left_center_y), 5, (0, 255, 0), -1)
                    else:
                        left_center_x = None
                        left_center_y = None

                    # 오른쪽 차선의 무게중심 계산 및 표시
                    if len(rightx) > 0 and len(righty) > 0:
                        right_center_x = int(np.mean(rightx))
                        right_center_y = int(np.mean(righty))
                        cv2.circle(undist_frame, (right_center_x, right_center_y), 5, (0, 255, 0), -1)
                    else:
                        right_center_x = None
                        right_center_y = None

                    # 두 차선 무게중심의 중앙점 계산 및 표시
                    if left_center_x is not None and right_center_x is not None:
                        mid_center_x = int((left_center_x + right_center_x) / 2)
                        mid_center_y = int((left_center_y + right_center_y) / 2)
                        cv2.circle(undist_frame, (mid_center_x, mid_center_y), 5, (255, 0, 0), -1)

                        # 이미지 중앙과의 편차 계산
                        image_center_x = undist_frame.shape[1] // 2
                        deviation = mid_center_x - image_center_x

                        # 모터 값 계산 및 전송
                        max_speed = 100  # 최대 속도
                        base_speed = 50  # 기본 속도
                        max_deviation = undist_frame.shape[1] // 2

                        normalized_deviation = deviation / max_deviation
                        normalized_deviation = np.clip(normalized_deviation, -1, 1)

                        left_speed = base_speed - (normalized_deviation * base_speed)
                        right_speed = base_speed + (normalized_deviation * base_speed)

                        left_speed = int(np.clip(left_speed, 0, max_speed))
                        right_speed = int(np.clip(right_speed, 0, max_speed))
                        
                        
                        # # 수정된 코드:
                        # command_id = 'M'

                        # motor_command = struct.pack('2shh', command_id.encode('utf-8'), left_speed, right_speed)
                        # motor_command += b'\n'
                        # print(f"Sending motor command: {command_id} with speeds L: {left_speed}, R: {right_speed}")

                        #motor_command = b'M' + bytes([left_speed, right_speed]) + b'\n'
                        
                        # motor_command = bytes([10, left_speed, right_speed]) + b'\n'
                        # motor_command = b'M' + b'R' if deviation > 0 else b'L' + right_speed.to_bytes(2, byteorder="big") + b'\n'

                        # motor_command = b"M" + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n"                        

                        # rpi_conn.sendall(motor_command)
                        # print(f"send motor_command {motor_command}")

                    # 화면에 디버그용으로 표시
                    lane_overlay = np.zeros_like(undist_frame)
                    lane_overlay[preprocessImage == 255] = [0, 0, 255]
                    combined = cv2.addWeighted(undist_frame, 0.7, lane_overlay, 1.0, 0)
                    cv2.imshow("Lane Detection", combined)

                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        break
                else:
                    print("Error: Unable to decode frame")

            # status data
            elif header == b'CS':
                status_data = b''
                while len(status_data) < 1:
                    packet = rpi_conn.recv(1 - len(status_data))
                    if not packet:
                        break
                    status_data += packet

                rpi_conn.recv(1)  # \n 받기

                status = int.from_bytes(status_data, byteorder="big")
                if status == 1:
                    print("status:", status)
                else:
                    print("status", status)

    except Exception as e:
        print(f"Error receiving or displaying frame: {e}")

    finally:
        rpi_conn.close()
        cv2.destroyAllWindows()

def send_motor_value(rpi_conn):
    global left_speed, right_speed, robot_state
    while True:
        if robot_state == 0:
            break
        start = b'MC'
        motor_command = start + left_speed.to_bytes(1, byteorder="big") + right_speed.to_bytes(1, byteorder="big") + b"\n" 

        try:
            rpi_conn.sendall(motor_command)
            print(f"send motor_command {motor_command}")
        except Exception as e:
            print(f"Error sending motor command: {e}")
        
        time.sleep(1)  # 2~5초에 한번 쏴주는것만으로도 충분함. 타임 슬립없으면 충돌남.

def flower_detect_information(pollination_conn):
    global robot_state
    try:
        while True:
            if robot_state == 0:
                break
            header = b''
            while len(header) < 1:
                header += pollination_conn.recv(1 - len(header))

            # detect data
            if int.from_bytes(header, byteorder="big") == 22:
                size_data = b''
                print("get in header pollination")
                while len(size_data) < 2:
                    packet = pollination_conn.recv(2 - len(size_data))
                    if not packet:
                        break
                    size_data += packet
                data_size = int.from_bytes(size_data, byteorder="big")
                
                detect_data = b''
                while len(detect_data) < data_size:
                    packet = pollination_conn.recv(data_size - len(detect_data))
                    if not packet:
                        break
                    detect_data += packet

                pollination_conn.recv(1)  # \n 받기
                
                before_idx = 0
                for i in range(10, data_size, 10):
                    data = detect_data[before_idx : i]
                    before_idx = i
                    class_id = int.from_bytes(data[:2], byteorder="big")
                    x1 = int.from_bytes(data[2:4], byteorder="big")
                    y1 = int.from_bytes(data[4:6], byteorder="big")
                    x2 =int.from_bytes(data[6:8], byteorder="big")
                    y2 = int.from_bytes(data[8:], byteorder="big")
                    print(f"class : {class_id}, x1: {x1}, y1: {y1}, x2: {x2}, y2: {y2}")

    except Exception as e:
        print(f"Error receiving pollination data: {e}")

def get_robot_state(gui_conn, rpi_conn):
    global robot_state
    try:
        while True:
            header = b''
            while len(header) < 2:
                header += gui_conn.recv(2 - len(header))

            # detect data
            if header == b'RC':
                data = gui_conn.recv(2)
                state = int.from_bytes(data[:1], byteorder="big")
                print(f"get robot state: {state}")
                robot_state = state
                rpi_conn.sendall(header + data)

    except Exception as e:
        print(f"Error receiving robot state data: {e}")

def send_robot_state(gui_conn, rpi_conn):
    global robot_state
    time.sleep(20)
    try:
        command = 0
        start = b'RC'
        send_data = start + command.to_bytes(1, byteorder="big") + b'\n'
        gui_conn.sendall(send_data)
        rpi_conn.sendall(send_data)
        print(f"send robot state: {command}")

        robot_state = 0

    except Exception as e:
        print(f"Error sending robot state data: {e}")
                

if __name__ == "__main__" :

    # 서버 설정
    server_ip = "192.168.0.134"
    gui_server_port = 1234
    rpi_server_port = 3141
    pollination_server_port = 8888
    obs_server_port = 4040

    gui_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    gui_server_socket.bind((server_ip, gui_server_port))
    gui_server_socket.listen(1)
    print(f"서버가 {server_ip} : {gui_server_port}에서 대기 중입니다...")

    rpi_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    rpi_server_socket.bind((server_ip, rpi_server_port))
    rpi_server_socket.listen(1)
    print(f"서버가 {server_ip} : {rpi_server_port}에서 대기 중입니다...")

    obs_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    obs_server_socket.bind((server_ip, obs_server_port))
    obs_server_socket.listen(1)
    print(f"서버가 {server_ip} : {obs_server_port}에서 대기 중입니다...")

    pollination_server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    pollination_server_socket.bind((server_ip, pollination_server_port))
    pollination_server_socket.listen(1)
    print(f"서버가 {server_ip} : {pollination_server_port}에서 대기 중입니다...")

    gui_conn, addr = gui_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    rpi_conn, addr = rpi_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    obs_conn, addr = obs_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    pollination_conn, addr = pollination_server_socket.accept()
    print(f"클라이언트 {addr}와 연결되었습니다.")

    client_thread = Thread(target=handle_client, args=(rpi_conn, obs_conn))
    motor_cmd_thread = Thread(target=send_motor_value, args=(rpi_conn,))
    pollination_thread = Thread(target=flower_detect_information, args=(pollination_conn,))
    send_robot_thread = Thread(target=send_robot_state, args=(gui_conn, rpi_conn))
    get_robot_thread = Thread(target=get_robot_state, args=(gui_conn, rpi_conn))

    client_thread.start()
    motor_cmd_thread.start()
    pollination_thread.start()
    send_robot_thread.start()
    get_robot_thread.start()
    
    client_thread.join()
    motor_cmd_thread.join()
    pollination_thread.join()
    send_robot_thread.join()
    get_robot_thread.join()

    rpi_conn.close()
    rpi_server_socket.close()
    pollination_conn.close()
    pollination_server_socket.close()
    gui_conn.close()
    gui_server_socket.close()
    cv2.destroyAllWindows()
# Out:
# 서버가 192.168.0.134 : 1234에서 대기 중입니다...
# 서버가 192.168.0.134 : 3141에서 대기 중입니다...
# 서버가 192.168.0.134 : 4040에서 대기 중입니다...
# 서버가 192.168.0.134 : 8888에서 대기 중입니다...
# 클라이언트 ('192.168.0.34', 56362)와 연결되었습니다.
# 클라이언트 ('192.168.0.25', 47100)와 연결되었습니다.
# 클라이언트 ('192.168.0.147', 43126)와 연결되었습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 374
#     371 obs_conn, addr = obs_server_socket.accept()
#     372 print(f"클라이언트 {addr}와 연결되었습니다.")
# --> 374 pollination_conn, addr = pollination_server_socket.accept()
#     375 print(f"클라이언트 {addr}와 연결되었습니다.")
#     377 client_thread = Thread(target=handle_client, args=(rpi_conn, obs_conn))
#
# File /usr/lib/python3.10/socket.py:293, in socket.accept(self)
#     286 def accept(self):
#     287     """accept() -> (socket object, address info)
#     288
#     289     Wait for an incoming connection.  Return a new socket
#     290     representing the connection, and the address of the client.
#     291     For IP sockets, the address info is a pair (hostaddr, port).
#     292     """
# --> 293     fd, addr = self._accept()
#     294     sock = socket(self.family, self.type, self.proto, fileno=fd)
#     295     # Issue #7995: if no default timeout is set and the listening
#     296     # socket had a (non-zero) timeout, force the new socket in blocking
#     297     # mode to override platform-specific socket flags inheritance.
#
# KeyboardInterrupt:
